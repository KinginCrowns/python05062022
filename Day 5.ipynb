# %% [markdown]
# # loops

# %%
 word = 'python'
 for char in word:
    print(char)
# Out:
# p
# y
# t
# h
# o
# n

# %%
word = 'python'
for char in word:
    print(char * 3)
# Out:
# ppp
# yyy
# ttt
# hhh
# ooo
# nnn

# %%
names =['ade','Ojo','ade','kunle']
for name in names:
    print(f' hey, {name} this is for your kind reminder of the meeting scheduled to hold today by 5pm')
# Out:
#  hey, ade this is for your kind reminder of the meeting scheduled to hold today by 5pm
#  hey, Ojo this is for your kind reminder of the meeting scheduled to hold today by 5pm
#  hey, ade this is for your kind reminder of the meeting scheduled to hold today by 5pm
#  hey, kunle this is for your kind reminder of the meeting scheduled to hold today by 5pm

# %%
scores ={
    'james':98,
    'Samuel':85,
    'Mary':90,
    'John':87,
     'Ruth':48,
    'Samuel':92,
    'Jane':100
}

# %%
for key,value in scores.items():
    print(key,':',value)
# Out:
# james : 98
# Samuel : 92
# Mary : 90
# John : 87
# Ruth : 48
# Jane : 100

# %%
name = input('Please enter your name to check scores:')
for key in scores:
    if name == key:
        print(f'Congratulations your score is {scores[key]}')
    else:
        print('hey the records with the specified above name is not found')
# Out:
# Please enter your name to check scores:John
# Congratulations your score is 87
# hey the records with the specified above name is not found

# %% [markdown]
# # Break

# %%
name = input('Please enter your name to check scores:')
for key in scores:
    if name == key:
        print(f'Congratulations your score is {scores[key]}')
        break
    else:
        print('hey the records with the specified above name is not found')
# Out:
# Please enter your name to check scores:John
# hey the records with the specified above name is not found
# hey the records with the specified above name is not found
# hey the records with the specified above name is not found
# Congratulations your score is 87

# %%
name = input('Please enter your name to check scores:')
for key in scores:
    if name == key:
        print(f'Congratulations your score is {scores[key]}')
        continue
    else:
        print('hey the records with the specified above name is not found')
# Out:
# Please enter your name to check scores:John
# hey the records with the specified above name is not found
# hey the records with the specified above name is not found
# hey the records with the specified above name is not found
# Congratulations your score is 87
# hey the records with the specified above name is not found
# hey the records with the specified above name is not found

# %%
name = input('Please enter your name to check scores:')
for key in scores:
    if name == key:
        print(f'Congratulations your score is {scores[key]}')
        break
else:
    print('hey the records with the specified above name is not found')
# Out:
# Please enter your name to check scores:Clement
# hey the records with the specified above name is not found

# %% [markdown]
# # while loop #it is used when you want to meet a  certain condition

# %%
import math
count = 0
num = int(input('Please provide a number:'))
while num!= 0:
    print(math.sqrt(num))
    count = count + 1
    num = int(input('Please provide a number:'))
# Out:
# Please provide a number:45
# 6.708203932499369
# Please provide a number:7
# 2.6457513110645907
# Please provide a number:6
# 2.449489742783178
# Please provide a number:1
# 1.0
# Please provide a number:0

# %%
import random as rn
number = []
counter = 1
while counter <= 100:
    num = rn.randint(45,70)
    number.append(num)
    counter +=1

# %%
print(number)
# Out:
# [65, 69, 54, 68, 60, 60, 52, 68, 56, 55, 67, 55, 55, 56, 49, 53, 67, 62, 45, 63, 70, 69, 64, 61, 60, 64, 46, 52, 55, 59, 50, 63, 60, 56, 61, 69, 64, 67, 49, 48, 63, 57, 62, 55, 48, 65, 66, 60, 52, 51, 48, 67, 64, 70, 54, 62, 49, 64, 70, 65, 50, 70, 69, 51, 67, 58, 54, 57, 56, 59, 51, 48, 69, 70, 57, 59, 64, 45, 56, 59, 52, 69, 55, 57, 48, 52, 64, 59, 60, 54, 54, 47, 48, 54, 53, 62, 46, 56, 65, 47]

# %%
print(len(number))
# Out:
# 100

# %% [markdown]
# # writing a dice game using for loop

# %%
score1 = 0
score2 = 0

for i in range (1,11):
    dice1 = rn.randint(1,6)
    dice2 = rn.randint(1,6)
    
    if dice1  > dice2:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
player 1 WINS
    ''')
        score1 = score1 + 3
    elif dice2  > dice1:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
player 2 WINS
    ''')
        score2 = score2 + 3
    else:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
IT's A DRAW
    ''')
        score1 = score1 + 1
        score2 = score2 + 1
if score1 > score2:
    print(f'Congratulations player 1 is thr overall winner with total score of{score1}')
elif score2 > score1:
    print(f'Congratulations player 2 is the overall winner with total score of {score2}')
else:
    print('IT IS A DRAW')
# Out:
# Player 1 score:1
# player 2 score: 3
# player 2 WINS
#
# Player 1 score:4
# player 2 score: 6
# player 2 WINS
#
# Player 1 score:4
# player 2 score: 4
# IT's A DRAW
#
# Player 1 score:5
# player 2 score: 3
# player 1 WINS
#
# Player 1 score:5
# player 2 score: 1
# player 1 WINS
#
# Player 1 score:6
# player 2 score: 2
# player 1 WINS
#
# Player 1 score:3
# player 2 score: 1
# player 1 WINS
#
# Player 1 score:2
# player 2 score: 5
# player 2 WINS
#
# Player 1 score:6
# player 2 score: 1
# player 1 WINS
#
# Player 1 score:3
# player 2 score: 2
# player 1 WINS
#
# Congratulations player 1 is thr overall winner with total score of19

# %%
score1 = 0
score2 = 0
counter = 1

while counter <= 10:
    dice1 = rn.randint(1,6)
    dice2 = rn.randint(1,6)
    
    if dice1  > dice2:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
player 1 WINS
    ''')
        score1 = score1 + 3
    elif dice2  > dice1:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
player 2 WINS
    ''')
        score2 = score2 + 3
    else:
        print(f'''Player 1 score:{dice1}
player 2 score: {dice2}
IT's A DRAW
    ''')
        score1 = score1 + 1
        score2 = score2 + 1
    counter += 1    
if score1 > score2:
    print(f'Congratulations player 1 is thr overall winner with total score of{score1}')
elif score2 > score1:
    print(f'Congratulations player 2 is the overall winner with total score of {score2}')
else:
    print('IT IS A DRAW')
# Out:
# Player 1 score:6
# player 2 score: 4
# player 1 WINS
#
# Player 1 score:3
# player 2 score: 6
# player 2 WINS
#
# Player 1 score:5
# player 2 score: 3
# player 1 WINS
#
# Player 1 score:6
# player 2 score: 5
# player 1 WINS
#
# Player 1 score:6
# player 2 score: 2
# player 1 WINS
#
# Player 1 score:3
# player 2 score: 2
# player 1 WINS
#
# Player 1 score:2
# player 2 score: 1
# player 1 WINS
#
# Player 1 score:2
# player 2 score: 1
# player 1 WINS
#
# Player 1 score:6
# player 2 score: 4
# player 1 WINS
#
# Player 1 score:1
# player 2 score: 3
# player 2 WINS
#
# Congratulations player 1 is thr overall winner with total score of24
