# %% [markdown]
# #  ERROR HANDLING

# %%
# try 
# except
# else
# finally

# %%
try:
    num1 = int(input('Please provide the first number'))
    num2 = int(input('Please provide the second number'))
    print(num1 + num2)
    print(num1.upper())
except:
    print('you have encouter one or more errors')
# Out:
# Please provide the first number50
# Please provide the second number45
# 95
# you have encouter one or more errors

# %%
try:
    num1 = int(input('Please provide the first number'))
    num2 = int(input('Please provide the second number'))
    print(num1 + num2)
   # print(num1.upper())
except ValueError:
    print('Wrong value provided')
except AttributeError:
    print('Wrong funtion on integer attribute')
except:
    print('you have encouter one or more errors')
# Out:
# Please provide the first number50
# Please provide the second number50
# 100

# %%
try:
    num1 = int(input('Please provide the first number :'))
    num2 = int(input('Please provide the second number :'))
    print(num1 + num2)
   # print(num1.upper())
except ValueError:
    print('Wrong value provided')
except AttributeError:
    print('Wrong funtion on integer attribute')
except:
    print('you have encouter one or more errors')
else:
    print(num1 ** num2)
# Out:
# Please provide the first number :50
# Please provide the second number :50
# 100
# 8881784197001252323389053344726562500000000000000000000000000000000000000000000000000

# %%
try:
    num1 = int(input('Please provide the first number :'))
    num2 = int(input('Please provide the second number :'))
    print(num1 + num2)
   # print(num1.upper())
except ValueError:
    print('Wrong value provided')
except AttributeError:
    print('Wrong funtion on integer attribute')
except:
    print('you have encouter one or more errors')
else:
    print(num1 ** num2)
finally:
    print(num1/num2)
    print('End of program')
# Out:
# Please provide the first number :45
# Please provide the second number :5
# 50
# 184528125
# 9.0
# End of program

# %%
try:
    choice= input('''
    Please select the type of opration you want to perform:
    + for addition
    - for subtraction
    / for division
    * for multiplcation
    ''')
    num1 = int(input('Please provide the first number :  '))
    num2 = int(input('Please provide the second number : '))
    
    if choice == '+':
        print(f'{num1} + {num2} = {num1 + num2} ')
    
    elif choice == '-':
        print(f'{num1} - {num2} = {num1 - num2} ')
        
    elif choice == '*':
        print(f'{num1} * {num2} = {num1 * num2}')
        
    elif choice == '/':
        print(f'{num1} / {num2} = {num1 / num2}')
        
except TypeError:
    print('Invalid data type operation')
except ValueError:
    print('Wrong value provided')
except AttributeError:
    print('Wrong funtion on integer attribute')
except EOFError:
    print('One of the bracket is missing')
except ZeroDivisionError:
    print('a number cannot be divisible by Zero')
except:
    print('You have encountered on or more errors')
else:
    if num1 % 2==0  and num2 % 2 ==0:
        print('Both the value of num1 and num2 are even number')
    elif num1 % 2 !=0 and num2 % 2 !=0:
        print('Both the value of num1 and num2 are odd number')
    elif num1 % 2 !=0 and num2 % 2 ==0:
        print('The value of num1 is an odd number while the value num2 is an Even number')
    elif num1 % 2 ==0 and num2 % 2 !=0:
        print('The value of num1 is an Even number while the value num2 is an odd number')
finally:
    print('''HEY IT\'s INTRESTING TO BE A PROGRAMMER END OF PROGEAM''')
# Out:
#     Please select the type of opration you want to perform:
#     + for addition
#     - for subtraction
#     / for division
#     * for multiplcation
#     +
